# %% [markdown]
# # STAGE 2 - Data Preprocessing

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# Import Dataset
df = pd.read_csv("https://raw.githubusercontent.com/Refdinal/insight-hustler/refs/heads/master/data/aug_train.csv")

# %%
df.T
# Out:
#                                           0                       1      \
# enrollee_id                                8949                   29725
# city                                   city_103                 city_40
# city_development_index                     0.92                   0.776
# gender                                     Male                    Male
# relevent_experience     Has relevent experience  No relevent experience
# enrolled_university               no_enrollment           no_enrollment
# education_level                        Graduate                Graduate
# major_discipline                           STEM                    STEM
# experience                                  >20                      15
# company_size                                NaN                   50-99
# company_type                                NaN                 Pvt Ltd
# last_new_job                                  1                      >4
# training_hours                               36                      47
# target                                      1.0                     0.0
#
#                                          2                       3      \
# enrollee_id                              11561                   33241
# city                                   city_21                city_115
# city_development_index                   0.624                   0.789
# gender                                     NaN                     NaN
# relevent_experience     No relevent experience  No relevent experience
# enrolled_university           Full time course                     NaN
# education_level                       Graduate                Graduate
# major_discipline                          STEM         Business Degree
# experience                                   5                      <1
# company_size                               NaN                     NaN
# company_type                               NaN                 Pvt Ltd
# last_new_job                             never                   never
# training_hours                              83                      52
# target                                     0.0                     1.0
#
#                                           4                        5      \
# enrollee_id                                 666                    21651
# city                                   city_162                 city_176
# city_development_index                    0.767                    0.764
# gender                                     Male                      NaN
# relevent_experience     Has relevent experience  Has relevent experience
# enrolled_university               no_enrollment         Part time course
# education_level                         Masters                 Graduate
# major_discipline                           STEM                     STEM
# experience                                  >20                       11
# company_size                              50-99                      NaN
# company_type                     Funded Startup                      NaN
# last_new_job                                  4                        1
# training_hours                                8                       24
# target                                      0.0                      1.0
#
#                                           6                        7      \
# enrollee_id                               28806                      402
# city                                   city_160                  city_46
# city_development_index                     0.92                    0.762
# gender                                     Male                     Male
# relevent_experience     Has relevent experience  Has relevent experience
# enrolled_university               no_enrollment            no_enrollment
# education_level                     High School                 Graduate
# major_discipline                            NaN                     STEM
# experience                                    5                       13
# company_size                              50-99                      <10
# company_type                     Funded Startup                  Pvt Ltd
# last_new_job                                  1                       >4
# training_hours                               24                       18
# target                                      0.0                      1.0
#
#                                           8                        9      ...  \
# enrollee_id                               27107                      699  ...
# city                                   city_103                 city_103  ...
# city_development_index                     0.92                     0.92  ...
# gender                                     Male                      NaN  ...
# relevent_experience     Has relevent experience  Has relevent experience  ...
# enrolled_university               no_enrollment            no_enrollment  ...
# education_level                        Graduate                 Graduate  ...
# major_discipline                           STEM                     STEM  ...
# experience                                    7                       17  ...
# company_size                              50-99                   10000+  ...
# company_type                            Pvt Ltd                  Pvt Ltd  ...
# last_new_job                                  1                       >4  ...
# training_hours                               46                      123  ...
# target                                      1.0                      0.0  ...
#
#                                           19148                    19149  \
# enrollee_id                                9212                      251
# city                                    city_21                 city_103
# city_development_index                    0.624                     0.92
# gender                                      NaN                     Male
# relevent_experience     Has relevent experience  Has relevent experience
# enrolled_university               no_enrollment            no_enrollment
# education_level                         Masters                  Masters
# major_discipline                           STEM                     STEM
# experience                                    3                        9
# company_size                            100-500                    50-99
# company_type                            Pvt Ltd                  Pvt Ltd
# last_new_job                                  3                        1
# training_hours                               40                       36
# target                                      1.0                      1.0
#
#                                           19150                   19151  \
# enrollee_id                               32313                   11385
# city                                   city_160                city_149
# city_development_index                     0.92                   0.689
# gender                                   Female                    Male
# relevent_experience     Has relevent experience  No relevent experience
# enrolled_university               no_enrollment        Full time course
# education_level                        Graduate                Graduate
# major_discipline                           STEM                     NaN
# experience                                   10                       2
# company_size                            100-500                     NaN
# company_type                      Public Sector                     NaN
# last_new_job                                  3                       1
# training_hours                               23                      60
# target                                      0.0                     0.0
#
#                                           19152                   19153  \
# enrollee_id                               29754                    7386
# city                                   city_103                city_173
# city_development_index                     0.92                   0.878
# gender                                   Female                    Male
# relevent_experience     Has relevent experience  No relevent experience
# enrolled_university               no_enrollment           no_enrollment
# education_level                        Graduate                Graduate
# major_discipline                     Humanities              Humanities
# experience                                    7                      14
# company_size                              10/49                     NaN
# company_type                     Funded Startup                     NaN
# last_new_job                                  1                       1
# training_hours                               25                      42
# target                                      0.0                     1.0
#
#                                           19154                    19155  \
# enrollee_id                               31398                    24576
# city                                   city_103                 city_103
# city_development_index                     0.92                     0.92
# gender                                     Male                     Male
# relevent_experience     Has relevent experience  Has relevent experience
# enrolled_university               no_enrollment            no_enrollment
# education_level                        Graduate                 Graduate
# major_discipline                           STEM                     STEM
# experience                                   14                      >20
# company_size                                NaN                    50-99
# company_type                                NaN                  Pvt Ltd
# last_new_job                                  4                        4
# training_hours                               52                       44
# target                                      1.0                      0.0
#
#                                           19156                   19157
# enrollee_id                                5756                   23834
# city                                    city_65                 city_67
# city_development_index                    0.802                   0.855
# gender                                     Male                     NaN
# relevent_experience     Has relevent experience  No relevent experience
# enrolled_university               no_enrollment           no_enrollment
# education_level                     High School          Primary School
# major_discipline                            NaN                     NaN
# experience                                   <1                       2
# company_size                            500-999                     NaN
# company_type                            Pvt Ltd                     NaN
# last_new_job                                  2                       1
# training_hours                               97                     127
# target                                      0.0                     0.0
#
# [14 rows x 19158 columns]

# %% [markdown]
# **Features**
#
# - enrollee_id : Unique ID for enrollee
# - city: City code
# - citydevelopmentindex: Developement index of *the* - city (scaled)
# - gender: Gender of enrolee
# - relevent_experience: Relevent experience of enrolee
# - enrolled_university: Type of University course enrolled if any
# - education_level: Education level of enrolee
# - major_discipline :Education major discipline of enrolee
# - experience: Enrolee total experience in years
# - company_size: No of employees in current employer's company
# - company_type : Type of current employer
# - lastnewjob: Difference in years between previous job and current job
# - training_hours: training hours completed
# - target: 0 – Not looking for job change, 1 – Looking for a job change

# %% [markdown]
# # 1.DATA CLEANSING

# %% [markdown]
# ## a. Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 2.0+ MB

# %%
print(" \t Columns with null \n -->",df.columns[df.isnull().any()])
# Out:
#  	 Columns with null
#  --> Index(['gender', 'enrolled_university', 'education_level', 'major_discipline',
#        'experience', 'company_size', 'company_type', 'last_new_job'],
#       dtype='object')

# %% [markdown]
# - Hanya kolom city, city development index, relevent experience, training hours and target yang tidak memiliki missing values

# %%
df.isna().sum()/len(df)
# Out:
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# gender                    0.235306
# relevent_experience       0.000000
# enrolled_university       0.020148
# education_level           0.024011
# major_discipline          0.146832
# experience                0.003393
# company_size              0.309949
# company_type              0.320493
# last_new_job              0.022080
# training_hours            0.000000
# target                    0.000000
# dtype: float64

# %%
# Cleansing and handling missing value
df['last_new_job'] = df['last_new_job'].apply(lambda x: 'Never' if x == 'never' else x) #just reads nicer
df['enrolled_university'][df['enrolled_university'] == 'no_enrollment'] = 'No Enrollment' #just reads nicer
df['company_size'] = df['company_size'].apply(lambda x: '10-49' if x == '10/49' else x) #diff replacement method

df['experience'] = df['experience'].apply(lambda x: '0' if x == '<1' else x)
df['experience'] = df['experience'].apply(lambda x: '21' if x == '>20' else x)


df['company_size'].fillna('0',inplace=True)
df['company_type'].fillna('Unknown',inplace=True)
df['major_discipline'].fillna('Unknown',inplace=True)
df['gender'].fillna('Other',inplace=True)


# This is what I mean with respect to the gender categories:

df['target'].groupby(df['gender']).mean()
# Out:
# gender
# Female    0.263328
# Male      0.227819
# Other     0.306235
# Name: target, dtype: float64

# %%
df.isna().sum()/len(df)
# Out:
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# gender                    0.000000
# relevent_experience       0.000000
# enrolled_university       0.020148
# education_level           0.024011
# major_discipline          0.000000
# experience                0.003393
# company_size              0.000000
# company_type              0.000000
# last_new_job              0.022080
# training_hours            0.000000
# target                    0.000000
# dtype: float64

# %%
df.dropna(inplace=True)
df.dropna(inplace=True)
df.isna().sum()/len(df)
# Out:
# enrollee_id               0.0
# city                      0.0
# city_development_index    0.0
# gender                    0.0
# relevent_experience       0.0
# enrolled_university       0.0
# education_level           0.0
# major_discipline          0.0
# experience                0.0
# company_size              0.0
# company_type              0.0
# last_new_job              0.0
# training_hours            0.0
# target                    0.0
# dtype: float64

# %% [markdown]
# ## b. Duplicated data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# data ini tidak memiliki data duplikat

# %%
# pengelompokan kolom berdasarkan jenisnya
cats = ['city', 'gender', 'relevent_experience', 'enrolled_university', 'major_discipline', 'experience', 'company_size', 'company_type', 'last_new_job']
nums = ['city_development_index', 'training_hours', 'target']

# %%
df[cats].describe().T
# Out:
#                      count unique                      top   freq
# city                 18014    123                 city_103   4194
# gender               18014      3                     Male  12772
# relevent_experience  18014      2  Has relevent experience  13190
# enrolled_university  18014      3            No Enrollment  13348
# major_discipline     18014      7                     STEM  13993
# experience           18014     22                       21   3182
# company_size         18014      9                        0   5310
# company_type         18014      7                  Pvt Ltd   9475
# last_new_job         18014      6                        1   7789

# %%
df[nums].describe().T
# Out:
#                           count       mean        std    min     25%    50%  \
# city_development_index  18014.0   0.831728   0.122115  0.448   0.745   0.91
# training_hours          18014.0  65.347896  60.059220  1.000  23.000  47.00
# target                  18014.0   0.245420   0.430348  0.000   0.000   0.00
#
#                           75%      max
# city_development_index   0.92    0.949
# training_hours          88.00  336.000
# target                   0.00    1.000

# %% [markdown]
# ## c. Outlier

# %%
df['city_development_index'].describe()
# Out:
# count    18014.000000
# mean         0.831728
# std          0.122115
# min          0.448000
# 25%          0.745000
# 50%          0.910000
# 75%          0.920000
# max          0.949000
# Name: city_development_index, dtype: float64

# %%
sns.histplot(df['city_development_index'],bins=10,kde=True)
plt.show()

# %% [markdown]
# - City development index memiliki nilai minimum 0.448000 dan nilai maximum 0.949000
# - Mean  0.828848 and Standard Deviation 0.123362

# %%
sns.boxplot(df['city_development_index'])
plt.show()

# %%
df['training_hours'].describe()
# Out:
# count    18014.000000
# mean        65.347896
# std         60.059220
# min          1.000000
# 25%         23.000000
# 50%         47.000000
# 75%         88.000000
# max        336.000000
# Name: training_hours, dtype: float64

# %%
sns.histplot(df['training_hours'],bins=10,kde=True)
plt.show()

# %% [markdown]
# - Training Hours index memiliki nilai minimum 1 dan nilai maximum 336
# - Mean 65.366896 dan Standard Deviation 60.058462

# %%
sns.boxplot(df['training_hours'])
plt.show()

# %%
df['target'].describe()
# Out:
# count    18014.000000
# mean         0.245420
# std          0.430348
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: target, dtype: float64

# %%
sns.histplot(df['target'],bins=10,kde=True)
plt.show()

# %% [markdown]
# - Target memiliki nilai minimum 0 dan nilai maximum  1
# - Mean  0.249348 dan Standard Deviation 0.432647

# %%
sns.boxplot(df['target'])
plt.show()

# %%
fig, axes = plt.subplots(len(nums), 1, figsize=(10, 20))
for i, feature in enumerate(nums):
    sns.boxplot(x='target', y=feature, data=df, ax=axes[i])
    axes[i].set_title(f'{feature} vs target (Before Handling Outliers)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Boxplot menampilkan distribusi data numerik dan memungkinkan identifikasi outlier sebagai titik-titik yang berada di luar "whiskers" dari boxplot. Ini memberikan pandangan awal tentang bagaimana distribusi fitur numerik terkait dengan variabel target y dan menunjukkan adanya outlier.

# %%
fig, axes = plt.subplots(len(cats), 1, figsize=(10, 40))
for i, feature in enumerate(cats):
    sns.countplot(x=feature, hue='target', data=df, ax=axes[i])
    axes[i].set_title(f'{feature} vs targer (Before Handling Outliers)')
    axes[i].legend(title='target', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Countplot menampilkan distribusi fitur kategorikal dengan menghitung jumlah kemunculan setiap kategori, dibagi berdasarkan variabel target . Ini membantu memahami bagaimana kategori dalam setiap fitur terkait dengan variabel target.

# %% [markdown]
# Handling outlier
# 1. city_development_index
# - Outlier sedikit dan berpotensi memiliki makna penting dalam kaitannya dengan target (kondisi kota dapat memengaruhi pencarian pekerjaan).
# 2. training_hours
# - Banyak outlier ekstrem (>200 jam) yang dapat mendistorsi distribusi dan memengaruhi model, terutama model sensitif terhadap skala data.

# %% [markdown]
# ## d. Feature Transformation

# %% [markdown]
# ### Transformasi Feature Numeric
# 1. city_development_index
# Tidak perlu dilakukan transformasi feature
# 2. training_hours
# Perlu dilakukan transformasi log untuk membuat data ke arah distribusi normal

# %% [markdown]
# #### Feature: city_development_index

# %%
# Distribusi target dan fitur dengan city_development_index
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df[df['target'] == 0]['city_development_index'], label='Target 0', shade=True)
sns.kdeplot(data=df[df['target'] == 1]['city_development_index'], label='Target 1', shade=True)
plt.title('KDE Plot: City Development Index by Target')
plt.xlabel('City Development Index')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# #### Feature: training_hours

# %%
# Distribusi Training Hours dengan Target Sebelum Transformasi log
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df[df['target'] == 0]['training_hours'], label='Target 0', shade=True)
sns.kdeplot(data=df[df['target'] == 1]['training_hours'], label='Target 1', shade=True)
plt.title('KDE Plot: Training Hours by Target (Before Log Transformation)')
plt.xlabel('Training Hours')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
# transformasi log
df['training_hours'] = np.log1p(df['training_hours'])

# %%
# Distribusi Training Hours dengan Target Setelah Transformasi log
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df[df['target'] == 0]['training_hours'], label='Target 0', shade=True)
sns.kdeplot(data=df[df['target'] == 1]['training_hours'], label='Target 1', shade=True)
plt.title('KDE Plot: Training Hours by Target (After Log Transformation)')
plt.xlabel('Training Hours')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
from scipy.stats import zscore

# Menyimpan shape data sebelum penghapusan outlier
print("Sebelum Menghapus Outlier:", df.shape)

# Menghapus outlier berdasarkan z-score
df = df[(zscore(df['training_hours']) > -3) & (zscore(df['training_hours']) < 3)]

# Menyimpan shape data setelah penghapusan outlier
print("Setelah Menghapus Outlier:", df.shape)
# Out:
# Sebelum Menghapus Outlier: (18014, 14)
# Setelah Menghapus Outlier: (18005, 14)

# %% [markdown]
# ## e. Feature encoding

# %% [markdown]
# ### Label Encoding
# Label Encoding dilakukan pada :
# 1. feature categorical yang memiliki tipe data ordinal (dapat diurutkan)
# 2. feature yang hanya memiliki 2 categorical data

# %% [markdown]
# #### Feature : relevent_experience

# %%
# Sebelum Encoding
plt.title('relevent_experience sebelum label encoding')
sns.countplot(x="relevent_experience", data = df)
plt.xticks(rotation = 0)
plt.show()

# %%
df["relevent_experience"] = [ 1 if i == "Has relevent experience"
                                    else 0 for i in df["relevent_experience"]]

# %%
# Setelah Encoding
plt.title('relevent_experience setelah label encoding')
sns.countplot(x="relevent_experience", data = df)
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# #### Feature : education_level

# %%
# Sebelum Encoding
plt.title('education_level sebelum label encoding')
sns.countplot(x="education_level", data = df)
plt.xticks(rotation = 30)
plt.show()

# %%
df["education_level"] = [ 5 if i == "Phd"
                                    else 4 if i == "Masters"
                                    else 3 if i == "Graduate"
                                    else 2 if i == "High School"
                                    else 1 for i in df["education_level"]]

# %%
# Setelah Encoding
plt.title('education_level setelah label encoding')
sns.countplot(x="education_level", data = df)
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# #### Feature : experience
# pada data cleansing sebelumnya nilai unique <1 diubah jadi 0, dan >20 diubah jadi 21. type data yang masih object cukup diubah ke numeric

# %%
# Sebelum
plt.title('experience sebelum label encoding')
sns.countplot(x="experience", data = df)
plt.xticks(rotation = 0)
plt.show()

# %%
# df["experience"] = [ 0 if i == "2" or i == "1" or i == "4" or i == "<1" or i == "3"
#                                     else 1 if i == "5>" or i == "11" or i == "7" or i == "10" or i == "6" or i == "9" or i == "8" or i == "20"
#                                     else 2 for i in df["experience"]]
df['experience'] = df['experience'].astype(int)

# %%
# Sesudah
plt.title('experience setelah label encoding')
sns.countplot(x="experience", data = df)
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# #### Feature last_new_job

# %%
# Sebelum encoding
plt.title('last_new_job sebelum label encoding')
sns.countplot(x="last_new_job", data = df)
plt.xticks(rotation = 0)
plt.show()

# %%
df["last_new_job"] = [ 5 if i == ">4"
                               else 4 if i == "4"
                               else 3 if i == "3"
                               else 2 if i == "2"
                               else 1 if i == "1"
                               else 0 for i in df["last_new_job"]]

# %%
# Setelah encoding
plt.title('last_new_job setelah label encoding')
sns.countplot(x="last_new_job", data = df)
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# ### One Hot Encoding
# One-hot encoding dilakukan pada categorical data yang bukan tipe data ordinal(dapat diurutkan)

# %% [markdown]
# #### Feature : gender

# %%
plt.title('gender distribusi')
sns.countplot(x="gender", data = df)
plt.xticks(rotation = 60)
plt.show()

# %%
# gender
# male = 0 , female = 1, other = 2
# df["gender"] = [ 0 if gender == "Male"
#                         else 1 if gender == "Female"
#                         else 2 for gender in df["gender"]]
df = pd.get_dummies(df, columns=['gender'], drop_first=False)

# %%
df.T.tail(3).T
# Out:
#       gender_Female gender_Male gender_Other
# 0                 0           1            0
# 1                 0           1            0
# 2                 0           0            1
# 4                 0           1            0
# 5                 0           0            1
# ...             ...         ...          ...
# 19153             0           1            0
# 19154             0           1            0
# 19155             0           1            0
# 19156             0           1            0
# 19157             0           0            1
#
# [18005 rows x 3 columns]

# %% [markdown]
# #### Feature : enrolled_university

# %%
# Distribution Check
plt.title('enrolled_university distribusi')
sns.countplot(x="enrolled_university", data = df)
plt.xticks(rotation = 0)
plt.show()

# %%
# df["enrolled_university"] = [ 0 if i == "no_enrollment"
#                                     else 1 if i == "Full time course"
#                                     else 2 for i in df["enrolled_university"]]

# One-hot Encoding
df = pd.get_dummies(df, columns=['enrolled_university'], drop_first=False)

# %%
# Feature setelah One-Hot Encoding
df.T.tail(3).T
# Out:
#       enrolled_university_Full time course enrolled_university_No Enrollment  \
# 0                                        0                                 1
# 1                                        0                                 1
# 2                                        1                                 0
# 4                                        0                                 1
# 5                                        0                                 0
# ...                                    ...                               ...
# 19153                                    0                                 1
# 19154                                    0                                 1
# 19155                                    0                                 1
# 19156                                    0                                 1
# 19157                                    0                                 1
#
#       enrolled_university_Part time course
# 0                                        0
# 1                                        0
# 2                                        0
# 4                                        0
# 5                                        1
# ...                                    ...
# 19153                                    0
# 19154                                    0
# 19155                                    0
# 19156                                    0
# 19157                                    0
#
# [18005 rows x 3 columns]

# %% [markdown]
# #### Feature : major_discipline

# %%
# Cek distribusi
plt.title('major_discipline distribusi')
sns.countplot(x="major_discipline", data = df)
plt.xticks(rotation = 30)
plt.show()

# %%
# df["major_discipline"] = [ 0 if i == "STEM"
#                                     else 1 if i == "Humanities"
#                                     else 2 if i == "Business Degree"
#                                     else 3 if i == "Arts"
#                                     else 4 if i == "No Major"
#                                     else 5 if i == "unknown"
#                                     else 6 for i in df["major_discipline"]]

# One-hot Encoding
df = pd.get_dummies(df, columns=['major_discipline'], drop_first=False)

# %%
# Feature setelah One-Hot Encoding
df.T.tail(7).T
# Out:
#       major_discipline_Arts major_discipline_Business Degree  \
# 0                         0                                0
# 1                         0                                0
# 2                         0                                0
# 4                         0                                0
# 5                         0                                0
# ...                     ...                              ...
# 19153                     0                                0
# 19154                     0                                0
# 19155                     0                                0
# 19156                     0                                0
# 19157                     0                                0
#
#       major_discipline_Humanities major_discipline_No Major  \
# 0                               0                         0
# 1                               0                         0
# 2                               0                         0
# 4                               0                         0
# 5                               0                         0
# ...                           ...                       ...
# 19153                           1                         0
# 19154                           0                         0
# 19155                           0                         0
# 19156                           0                         0
# 19157                           0                         0
#
#       major_discipline_Other major_discipline_STEM major_discipline_Unknown
# 0                          0                     1                        0
# 1                          0                     1                        0
# 2                          0                     1                        0
# 4                          0                     1                        0
# 5                          0                     1                        0
# ...                      ...                   ...                      ...
# 19153                      0                     0                        0
# 19154                      0                     1                        0
# 19155                      0                     1                        0
# 19156                      0                     0                        1
# 19157                      0                     0                        1
#
# [18005 rows x 7 columns]

# %% [markdown]
# #### Feature: company_size
# dikarenakan 0 tidak cocok untuk mengisi missing value maka dibuat menjadi kategori baru 'unknown'. sehingga dibagi menjadi
# - Small: <10, 10-49, 50-99
# - Medium: 100-500, 500-999
# - Large: 1000-4999, 5000-9999
# - Unknown: Any undefined or missing values (e.g., '0')

# %%
# Sebelum Encoding
plt.title('company_size distribusi')
sns.countplot(x="company_size", data = df)
plt.xticks(rotation = 60)
plt.show()

# %%
# df["company_size"] = [ 0 if i == '0'
#                       else 1 if i == '<10'
#                       else 2 if i == '10-49'
#                       else 3 if i == '50-99'
#                       else 4 if i == '100-500'
#                       else 5 if i == '500-999'
#                       else 6 if i == '1000-4999'
#                       else 7 if i == '5000-9999'
#                       else 8 for i in df["company_size"]]

# buat kategori baru
df["company_size"] = df["company_size"].apply(
    lambda x: "Small" if x in ['<10', '10-49', '50-99'] else
              "Medium" if x in ['100-500', '500-999'] else
              "Large" if x in ['1000-4999', '5000-9999'] else
              "Unknown"  # For '0' or missing values
)

# %%
# kategori baru
plt.title('company_size kategori baru')
sns.countplot(x="company_size", data = df)
plt.xticks(rotation = 60)
plt.show()

# %%
# One-Hot Encoding
df = pd.get_dummies(df, columns=['company_size'], drop_first=False)

# %%
# Feature setelah One-Hot Encoding
df.T.tail(4).T
# Out:
#       company_size_Large company_size_Medium company_size_Small  \
# 0                      0                   0                  0
# 1                      0                   0                  1
# 2                      0                   0                  0
# 4                      0                   0                  1
# 5                      0                   0                  0
# ...                  ...                 ...                ...
# 19153                  0                   0                  0
# 19154                  0                   0                  0
# 19155                  0                   0                  1
# 19156                  0                   1                  0
# 19157                  0                   0                  0
#
#       company_size_Unknown
# 0                        1
# 1                        0
# 2                        1
# 4                        0
# 5                        1
# ...                    ...
# 19153                    1
# 19154                    1
# 19155                    0
# 19156                    0
# 19157                    1
#
# [18005 rows x 4 columns]

# %% [markdown]
# #### Feature: company_type

# %%
# Sebelum Encoding
plt.title('company_type distribusi')
sns.countplot(x="company_type", data = df)
plt.xticks(rotation = 30)
plt.show()

# %%
# df["company_type"] = [ 0 if i == "Pvt Ltd"
#                                else 1 if i == "Funded Startup"
#                                else 2 if i == "Public Sector"
#                                else 3 if i == "Early Stage Startup"
#                                else 4 if i == "NGO"
#                                else 5 for i in df["company_type"]]

# One-Hot Encoding
df = pd.get_dummies(df, columns=['company_type'], drop_first=False)

# %%
# Feature setelah One-Hot Encoding
df.T.tail(7).T
# Out:
#       company_type_Early Stage Startup company_type_Funded Startup  \
# 0                                    0                           0
# 1                                    0                           0
# 2                                    0                           0
# 4                                    0                           1
# 5                                    0                           0
# ...                                ...                         ...
# 19153                                0                           0
# 19154                                0                           0
# 19155                                0                           0
# 19156                                0                           0
# 19157                                0                           0
#
#       company_type_NGO company_type_Other company_type_Public Sector  \
# 0                    0                  0                          0
# 1                    0                  0                          0
# 2                    0                  0                          0
# 4                    0                  0                          0
# 5                    0                  0                          0
# ...                ...                ...                        ...
# 19153                0                  0                          0
# 19154                0                  0                          0
# 19155                0                  0                          0
# 19156                0                  0                          0
# 19157                0                  0                          0
#
#       company_type_Pvt Ltd company_type_Unknown
# 0                        0                    1
# 1                        1                    0
# 2                        0                    1
# 4                        0                    0
# 5                        0                    1
# ...                    ...                  ...
# 19153                    0                    1
# 19154                    0                    1
# 19155                    1                    0
# 19156                    1                    0
# 19157                    0                    1
#
# [18005 rows x 7 columns]

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index  relevent_experience  \
# 0         8949  city_103                   0.920                    1
# 1        29725   city_40                   0.776                    0
# 2        11561   city_21                   0.624                    0
# 4          666  city_162                   0.767                    1
# 5        21651  city_176                   0.764                    1
#
#    education_level  experience  last_new_job  training_hours  target  \
# 0                3          21             1        3.610918     1.0
# 1                3          15             5        3.871201     0.0
# 2                3           5             0        4.430817     0.0
# 4                4          21             4        2.197225     0.0
# 5                3          11             1        3.218876     1.0
#
#    gender_Female  ...  company_size_Medium  company_size_Small  \
# 0              0  ...                    0                   0
# 1              0  ...                    0                   1
# 2              0  ...                    0                   0
# 4              0  ...                    0                   1
# 5              0  ...                    0                   0
#
#    company_size_Unknown  company_type_Early Stage Startup  \
# 0                     1                                 0
# 1                     0                                 0
# 2                     1                                 0
# 4                     0                                 0
# 5                     1                                 0
#
#    company_type_Funded Startup  company_type_NGO  company_type_Other  \
# 0                            0                 0                   0
# 1                            0                 0                   0
# 2                            0                 0                   0
# 4                            1                 0                   0
# 5                            0                 0                   0
#
#    company_type_Public Sector  company_type_Pvt Ltd  company_type_Unknown
# 0                           0                     0                     1
# 1                           0                     1                     0
# 2                           0                     0                     1
# 4                           0                     0                     0
# 5                           0                     0                     1
#
# [5 rows x 33 columns]

# %% [markdown]
# ## f. Class Imbalance

# %%
counts = df['target'].value_counts()

# Membuat pie chart
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=[f'Class {x}' for x in counts.index], autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#99ff99'])
plt.title('Distribution of Target Classes')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is drawn as a circle.
plt.show()

# %% [markdown]
# - 24.5 persen employee memilih mencari pekerjaan baru
# - data imbalance ini akan dihandle saat sebelum modelling / menggunakan model yang robust terhadap imbalance data

# %%
# Handling class imbalance
X = df.drop(columns=['enrollee_id', 'city','target'])
y = df['target']
# import library
from imblearn.over_sampling import SMOTE

# Hitung jumlah sampel dalam masing-masing kelas
from collections import Counter
counter = Counter(y)
majority_class = max(counter, key=counter.get)
minority_class = min(counter, key=counter.get)
n_majority = counter[majority_class]

# Tentukan rasio oversampling yang diinginkan (1:2)
sampling_strategy = {minority_class: int(n_majority / 2)}

# Inisialisasi SMOTE dengan sampling_strategy
smote = SMOTE(sampling_strategy=sampling_strategy, random_state=42)

# Terapkan SMOTE
X, y = smote.fit_resample(X, y)

# %%
counts = y.value_counts()

# Membuat pie chart
plt.figure(figsize=(6, 6))
plt.pie(counts, labels=[f'Class {x}' for x in counts.index], autopct='%1.1f%%', startangle=90, colors=['#66b3ff', '#99ff99'])
plt.title('Distribution of Target Classes After SMOTE')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is drawn as a circle.
plt.show()

# %% [markdown]
# # 2.Feature Engineering

# %% [markdown]
# ## a. Feature Selection

# %% [markdown]
# untuk enrolled id dan city yang tidak significant bisa dijadikan pertimbangan untuk di drop.

# %%
df_preprocessed = pd.concat([pd.DataFrame(X, columns=df.drop(columns=['enrollee_id', 'city','target']).columns), 
                          pd.Series(y, name='target')], axis=1)

# %%
# Cek deskripsi data
df_preprocessed.describe(include='all').T
# Out:
#                                         count       mean       std       min  \
# city_development_index                20379.0   0.823510  0.124650  0.448000
# relevent_experience                   20379.0   0.715099  0.451378  0.000000
# education_level                       20379.0   3.126895  0.671396  1.000000
# experience                            20379.0  10.036214  6.746090  0.000000
# last_new_job                          20379.0   1.984101  1.663031  0.000000
# training_hours                        20379.0   3.799445  0.932759  1.098612
# gender_Female                         20379.0   0.063153  0.243244  0.000000
# gender_Male                           20379.0   0.701065  0.457803  0.000000
# gender_Other                          20379.0   0.225575  0.417971  0.000000
# enrolled_university_Full time course  20379.0   0.202120  0.401591  0.000000
# enrolled_university_No Enrollment     20379.0   0.728299  0.444848  0.000000
# enrolled_university_Part time course  20379.0   0.059424  0.236422  0.000000
# major_discipline_Arts                 20379.0   0.012513  0.111162  0.000000
# major_discipline_Business Degree      20379.0   0.016095  0.125844  0.000000
# major_discipline_Humanities           20379.0   0.033417  0.179727  0.000000
# major_discipline_No Major             20379.0   0.010501  0.101937  0.000000
# major_discipline_Other                20379.0   0.018254  0.133872  0.000000
# major_discipline_STEM                 20379.0   0.781000  0.413579  0.000000
# major_discipline_Unknown              20379.0   0.118308  0.322980  0.000000
# company_size_Large                    20379.0   0.094411  0.292407  0.000000
# company_size_Medium                   20379.0   0.174493  0.379542  0.000000
# company_size_Small                    20379.0   0.299573  0.458082  0.000000
# company_size_Unknown                  20379.0   0.420973  0.493727  0.000000
# company_type_Early Stage Startup      20379.0   0.030227  0.171216  0.000000
# company_type_Funded Startup           20379.0   0.050199  0.218360  0.000000
# company_type_NGO                      20379.0   0.025124  0.156505  0.000000
# company_type_Other                    20379.0   0.005594  0.074585  0.000000
# company_type_Public Sector            20379.0   0.046371  0.210293  0.000000
# company_type_Pvt Ltd                  20379.0   0.506747  0.499967  0.000000
# company_type_Unknown                  20379.0   0.321998  0.467254  0.000000
# target                                20379.0   0.333333  0.471416  0.000000
#
#                                            25%       50%        75%        max
# city_development_index                0.706148  0.897000   0.920000   0.949000
# relevent_experience                   0.000000  1.000000   1.000000   1.000000
# education_level                       3.000000  3.000000   3.000000   5.000000
# experience                            4.000000  9.000000  15.000000  21.000000
# last_new_job                          1.000000  1.000000   3.000000   5.000000
# training_hours                        3.178054  3.871201   4.484359   5.820083
# gender_Female                         0.000000  0.000000   0.000000   1.000000
# gender_Male                           0.000000  1.000000   1.000000   1.000000
# gender_Other                          0.000000  0.000000   0.000000   1.000000
# enrolled_university_Full time course  0.000000  0.000000   0.000000   1.000000
# enrolled_university_No Enrollment     0.000000  1.000000   1.000000   1.000000
# enrolled_university_Part time course  0.000000  0.000000   0.000000   1.000000
# major_discipline_Arts                 0.000000  0.000000   0.000000   1.000000
# major_discipline_Business Degree      0.000000  0.000000   0.000000   1.000000
# major_discipline_Humanities           0.000000  0.000000   0.000000   1.000000
# major_discipline_No Major             0.000000  0.000000   0.000000   1.000000
# major_discipline_Other                0.000000  0.000000   0.000000   1.000000
# major_discipline_STEM                 1.000000  1.000000   1.000000   1.000000
# major_discipline_Unknown              0.000000  0.000000   0.000000   1.000000
# company_size_Large                    0.000000  0.000000   0.000000   1.000000
# company_size_Medium                   0.000000  0.000000   0.000000   1.000000
# company_size_Small                    0.000000  0.000000   1.000000   1.000000
# company_size_Unknown                  0.000000  0.000000   1.000000   1.000000
# company_type_Early Stage Startup      0.000000  0.000000   0.000000   1.000000
# company_type_Funded Startup           0.000000  0.000000   0.000000   1.000000
# company_type_NGO                      0.000000  0.000000   0.000000   1.000000
# company_type_Other                    0.000000  0.000000   0.000000   1.000000
# company_type_Public Sector            0.000000  0.000000   0.000000   1.000000
# company_type_Pvt Ltd                  0.000000  1.000000   1.000000   1.000000
# company_type_Unknown                  0.000000  0.000000   1.000000   1.000000
# target                                0.000000  0.000000   1.000000   1.000000

# %%
# Urutkan feature
columns_order =['city_development_index', 'relevent_experience', 'education_level',
       'experience', 'last_new_job', 'training_hours',
       'gender_Female', 'gender_Male', 'gender_Other',
       'enrolled_university_Full time course',
       'enrolled_university_No Enrollment',
       'enrolled_university_Part time course', 'major_discipline_Arts',
       'major_discipline_Business Degree', 'major_discipline_Humanities',
       'major_discipline_No Major', 'major_discipline_Other',
       'major_discipline_STEM', 'major_discipline_Unknown',
       'company_size_Large', 'company_size_Medium', 'company_size_Small',
       'company_size_Unknown', 'company_type_Early Stage Startup',
       'company_type_Funded Startup', 'company_type_NGO', 'company_type_Other',
       'company_type_Public Sector', 'company_type_Pvt Ltd',
       'company_type_Unknown','target']
df_preprocessed = df_preprocessed[columns_order]

# %%
# Membuat heatmap
plt.figure(figsize=(20, 20))
sns.heatmap(df_preprocessed.corr(), annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f', annot_kws={"size": 12, "rotation": 45})

# Menambahkan judul
plt.title('Heatmap of Correlation Matrix')

# Menampilkan plot
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = df_preprocessed.corr()

# Get the absolute values of the correlation matrix to consider both positive and negative correlations
abs_correlation_matrix = correlation_matrix.abs()

# Get the highest correlation for each variable
highest_correlation = abs_correlation_matrix.apply(lambda x: x[x != 1].max())

# Create a DataFrame or table to display the highest correlation for each variable
highest_correlation_df = pd.DataFrame(highest_correlation, columns=['Highest Correlation'])
highest_correlation_df.index.name = 'Variable'
highest_correlation_df.reset_index(inplace=True)

# Sort the DataFrame by highest correlation values in descending order
highest_correlation_df_sorted = highest_correlation_df.sort_values(by='Highest Correlation', ascending=False)

highest_correlation_df_sorted
# Out:
#                                 Variable  Highest Correlation
# 7                            gender_Male             0.826508
# 8                           gender_Other             0.826508
# 9   enrolled_university_Full time course             0.824033
# 10     enrolled_university_No Enrollment             0.824033
# 28                  company_type_Pvt Ltd             0.698509
# 29                  company_type_Unknown             0.698509
# 18              major_discipline_Unknown             0.691755
# 17                 major_discipline_STEM             0.691755
# 2                        education_level             0.680470
# 22                  company_size_Unknown             0.666347
# 21                    company_size_Small             0.557632
# 4                           last_new_job             0.478579
# 3                             experience             0.478579
# 11  enrolled_university_Part time course             0.411522
# 1                    relevent_experience             0.401334
# 6                          gender_Female             0.397607
# 20                   company_size_Medium             0.392018
# 0                 city_development_index             0.359065
# 30                                target             0.359065
# 14           major_discipline_Humanities             0.351128
# 19                    company_size_Large             0.275311
# 16                major_discipline_Other             0.257504
# 23      company_type_Early Stage Startup             0.250561
# 13      major_discipline_Business Degree             0.241531
# 24           company_type_Funded Startup             0.233019
# 27            company_type_Public Sector             0.223509
# 12                 major_discipline_Arts             0.212577
# 15             major_discipline_No Major             0.194541
# 25                      company_type_NGO             0.162716
# 26                    company_type_Other             0.076022
# 5                         training_hours             0.022277

# %% [markdown]
# Here are commonly accepted interpretations for Pearson correlation values:
#
# | Correlation Strength            | Absolute Value of r |
# |---------------------------------|----------------------|
# | **Strong correlation**          | r ≥ 0.7             |
# | **Moderate correlation**        | 0.5 ≤ r < 0.7       |
# | **Weak correlation**            | 0.3 ≤ r < 0.5       |
# | **Very weak or no correlation** | r < 0.3             |
#
# - Terdapat multikolinearitas kuat antara beberapa feature. Direkomendasikan untuk menggunakan model yang robust terhadap multikolinearitas

# %%
from scipy.stats import chi2_contingency

def run_chi_square_tests(df_preprocessed, significance_level=0.05):
    # Identify categorical columns
    cat_columns = df_preprocessed.columns

    # Store results
    results = []

    # Iterate through all pairs of categorical columns
    for i in range(len(cat_columns)):
        for j in range(i+1, len(cat_columns)):
            col1, col2 = cat_columns[i], cat_columns[j]

            # Create contingency table
            contingency_table = pd.crosstab(df[col1], df[col2])

            # Perform chi-square test
            chi2, p_value, dof, expected = chi2_contingency(contingency_table)

            # Check significance
            is_significant = p_value < significance_level

            # Store results
            results.append({
                'Column 1': col1,
                'Column 2': col2,
                'Chi-square': chi2,
                'p-value': p_value,
                'DoF': dof,
                'Significant': is_significant
            })

    # Convert results to DataFrame
    results_df = pd.DataFrame(results)
    return results_df

# %%
# Run chi-square tests
results = run_chi_square_tests(df_preprocessed)

# %%
results[(results['Significant'] == False) & (results['Column 2'] == 'target')]
# Out:
#                                  Column 1 Column 2  Chi-square   p-value  DoF  \
# 164                        training_hours   target  248.456383  0.323710  239
# 188                         gender_Female   target    1.307935  0.252769    1
# 293  enrolled_university_Part time course   target    0.000000  1.000000    1
# 311                 major_discipline_Arts   target    1.545580  0.213789    1
# 328      major_discipline_Business Degree   target    0.422951  0.515468    1
# 359             major_discipline_No Major   target    0.000000  1.000000    1
# 373                major_discipline_Other   target    0.030107  0.862248    1
# 443      company_type_Early Stage Startup   target    1.789501  0.180987    1
# 458                    company_type_Other   target    0.010947  0.916670    1
#
#      Significant
# 164        False
# 188        False
# 293        False
# 311        False
# 328        False
# 359        False
# 373        False
# 443        False
# 458        False

# %% [markdown]
# Terdapat beberapa feature yang tidak significant terhadap target, pada saat dilakuakn chi-square, bisa dijadikan pertimbangan untuk di drop apabila model tidak bagus kedepannya, untuk sekarang tidak di drop dulu.

# %%
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import chi2
# import pandas as pd

# # Misalkan df adalah DataFrame dengan kolom fitur dan target
# X = df.drop('target', axis=1)  # Fitur
# y = df['target']  # Target

# # Pilih fitur menggunakan Chi-Square
# chi2_selector = SelectKBest(chi2, k='all')  # 'all' untuk memilih semua fitur yang signifikan
# X_new = chi2_selector.fit_transform(X, y)

# # Tampilkan fitur yang terpilih
# selected_features = X.columns[chi2_selector.get_support()]
# print(selected_features)

# %% [markdown]
# ## b. Feature Extraction
# Untuk Sekarang Fitur yang digunakan berasal dari label encoding dan one-hot encoding dan beberapa fitur numerik

# %% [markdown]
# ## c. Feature Tambahan
# Tidak ada fitur tambahan untuk sementara. Fitur yang digunakan adalah hasil dari tranformasi fitur categorical menggunakan encoding

# %% [markdown]
# # 3.Github Repository
# [Go to Repository](https://github.com/Refdinal/insight-hustler)

# %% [markdown]
# simpan data hasil preprocessing

# %%
# from google.colab import files
# Simpan DataFrame ke file CSV
df_preprocessed.to_csv('data_preprocessed.csv', index=False)
